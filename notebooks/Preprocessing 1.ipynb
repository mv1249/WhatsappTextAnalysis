# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('WhatsApp-Chat-with-2018-2022-IT-B.csv')
df
# Out:
#       16/08/18, 20:12 - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 0      16/08/18, 20:11 - Chinmayee created group "AGI...
# 1                  16/08/18, 20:11 - Chinmayee added you
# 2      16/08/18, 20:12 - Chinmayee: Hello this is off...
# 3                16/08/18, 20:12 - Jagas: Chusinam leaaa
# 4       16/08/18, 20:12 - +91 6309 604 570: Admin cheyyi
# ...                                                  ...
# 14960  03/07/21, 13:03 - +91 90107 88369: Please join...
# 14961  03/07/21, 13:09 - Your security code with +91 ...
# 14962  03/07/21, 14:04 - +91 6304 605 703: All of you...
# 14963  03/07/21, 14:09 - +91 6304 605 703: Join the c...
# 14964  03/07/21, 15:04 - Nagalakshmi Ma'am 🐍💲: Please...
#
# [14965 rows x 1 columns]

# %%
df.columns = ['Data']
df.head()
# Out:
#                                                 Data
# 0  16/08/18, 20:11 - Chinmayee created group "AGI...
# 1              16/08/18, 20:11 - Chinmayee added you
# 2  16/08/18, 20:12 - Chinmayee: Hello this is off...
# 3            16/08/18, 20:12 - Jagas: Chusinam leaaa
# 4   16/08/18, 20:12 - +91 6309 604 570: Admin cheyyi

# %%
df['Data']
# Out:
# 0        16/08/18, 20:11 - Chinmayee created group "AGI...
# 1                    16/08/18, 20:11 - Chinmayee added you
# 2        16/08/18, 20:12 - Chinmayee: Hello this is off...
# 3                  16/08/18, 20:12 - Jagas: Chusinam leaaa
# 4         16/08/18, 20:12 - +91 6309 604 570: Admin cheyyi
#                                ...
# 14960    03/07/21, 13:03 - +91 90107 88369: Please join...
# 14961    03/07/21, 13:09 - Your security code with +91 ...
# 14962    03/07/21, 14:04 - +91 6304 605 703: All of you...
# 14963    03/07/21, 14:09 - +91 6304 605 703: Join the c...
# 14964    03/07/21, 15:04 - Nagalakshmi Ma'am 🐍💲: Please...
# Name: Data, Length: 14965, dtype: object

# %%
def startsWithDateAndTime(s):
    pattern = "^([0-9]+)(/)([0-9]+)(/)([0-9][0-9]), ([0-9]+):([0-9][0-9]) (AM|PM) -"
    result = re.match(pattern, s)
    if result:
        return True
    return False

# %%
datalist = list(df['Data'])
datalist
# Out:
# ['16/08/18, 20:11 - Chinmayee created group "AGI OFFICIAL@IT 2018-22"',
#  '16/08/18, 20:11 - Chinmayee added you',
#  '16/08/18, 20:12 - Chinmayee: Hello this is official grup',
#  '16/08/18, 20:12 - Jagas: Chusinam leaaa',
#  '16/08/18, 20:12 - +91 6309 604 570: Admin cheyyi',
#  '16/08/18, 20:12 - +91 6309 604 570: First',
#  '16/08/18, 20:12 - Kalyan: Kkkk',
#  '16/08/18, 20:12 - Chinmayee: No msg anything except studies',
#  '16/08/18, 20:12 - Chinmayee: Hello sirs kuda unarru',
#  '16/08/18, 20:12 - Chinmayee: Chusi matladu',
#  "16/08/18, 20:13 - You're now an admin",
#  '16/08/18, 20:13 - Jagas: Adhea kadha cheppindhiii',
#  '16/08/18, 20:13 - Chinmayee added Abhiramitb and S*2',
#  '16/08/18, 20:33 - Meet: Nc job',
#  '16/08/18, 20:41 - +91 91331 12884 left',
#  '16/08/18, 20:57 - Harifriend changed the subject from "AGI OFFICIAL@IT 2018-22" to "ONLY FOR STUDIES"',
#  '16/08/18, 21:07 - +91 99484 61869: This message was deleted',
# ...

# %%
datalist = [str(datalist[i]) for i in range(len(datalist))]
datasep = [datalist[i].split('-') for i in range(len(datalist))]
datasep
# Out:
# [['16/08/18, 20:11 ', ' Chinmayee created group "AGI OFFICIAL@IT 2018', '22"'],
#  ['16/08/18, 20:11 ', ' Chinmayee added you'],
#  ['16/08/18, 20:12 ', ' Chinmayee: Hello this is official grup'],
#  ['16/08/18, 20:12 ', ' Jagas: Chusinam leaaa'],
#  ['16/08/18, 20:12 ', ' +91 6309 604 570: Admin cheyyi'],
#  ['16/08/18, 20:12 ', ' +91 6309 604 570: First'],
#  ['16/08/18, 20:12 ', ' Kalyan: Kkkk'],
#  ['16/08/18, 20:12 ', ' Chinmayee: No msg anything except studies'],
#  ['16/08/18, 20:12 ', ' Chinmayee: Hello sirs kuda unarru'],
#  ['16/08/18, 20:12 ', ' Chinmayee: Chusi matladu'],
#  ['16/08/18, 20:13 ', " You're now an admin"],
#  ['16/08/18, 20:13 ', ' Jagas: Adhea kadha cheppindhiii'],
#  ['16/08/18, 20:13 ', ' Chinmayee added Abhiramitb and S*2'],
#  ['16/08/18, 20:33 ', ' Meet: Nc job'],
#  ['16/08/18, 20:41 ', ' +91 91331 12884 left'],
#  ['16/08/18, 20:57 ',
#   ' Harifriend changed the subject from "AGI OFFICIAL@IT 2018',
#   '22" to "ONLY FOR STUDIES"'],
# ...

# %%
datetime = [datasep[i][0] for i in range(len(datasep))]
datetime
# Out:
# ['16/08/18, 20:11 ',
#  '16/08/18, 20:11 ',
#  '16/08/18, 20:12 ',
#  '16/08/18, 20:12 ',
#  '16/08/18, 20:12 ',
#  '16/08/18, 20:12 ',
#  '16/08/18, 20:12 ',
#  '16/08/18, 20:12 ',
#  '16/08/18, 20:12 ',
#  '16/08/18, 20:12 ',
#  '16/08/18, 20:13 ',
#  '16/08/18, 20:13 ',
#  '16/08/18, 20:13 ',
#  '16/08/18, 20:33 ',
#  '16/08/18, 20:41 ',
#  '16/08/18, 20:57 ',
#  '16/08/18, 21:07 ',
#  '16/08/18, 21:07 ',
#  '16/08/18, 21:08 ',
#  '16/08/18, 21:33 ',
#  '16/08/18, 21:42 ',
#  '16/08/18, 21:44 ',
#  '17/08/18, 06:32 ',
#  '17/08/18, 06:32 ',
#  '17/08/18, 06:52 ',
#  '17/08/18, 06:53 ',
#  '17/08/18, 06:53 ',
#  '17/08/18, 06:53 ',
#  '17/08/18, 06:53 ',
#  '17/08/18, 06:54 ',
#  '17/08/18, 07:25 ',
#  '17/08/18, 07:26 ',
#  '17/08/18, 07:26 ',
#  '17/08/18, 07:26 ',
#  '17/08/18, 08:50 ',
#  '17/08/18, 08:51 ',
#  '17/08/18, 08:51 ',
#  '17/08/18, 08:51 ',
#  '17/08/18, 08:52 ',
#  '17/08/18, 08:52 ',
#  '17/08/18, 08:53 ',
#  '17/08/18, 08:53 ',
#  '17/08/18, 08:53 ',
# ...

# %%
print(len(datetime),len(datasep))
# Out:
# 14965 14965

# %%
datetime[0][0]
# Out:
# '1'

# %%
date = [datetime[i].split(',')[0] for i in range(len(datetime))]
date
# Out:
# ['16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '16/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
#  '17/08/18',
# ...

# %%
datetime[1].split(',')[1]
# Out:
# ' 20:11 '

# %%
time = []
for i in range(len(datetime)):
        
    try:
        
        time.append(datetime[i].split(',')[1])
        
    except:
        time.append(' ')

# %%
time
# Out:
# [' 20:11 ',
#  ' 20:11 ',
#  ' 20:12 ',
#  ' 20:12 ',
#  ' 20:12 ',
#  ' 20:12 ',
#  ' 20:12 ',
#  ' 20:12 ',
#  ' 20:12 ',
#  ' 20:12 ',
#  ' 20:13 ',
#  ' 20:13 ',
#  ' 20:13 ',
#  ' 20:33 ',
#  ' 20:41 ',
#  ' 20:57 ',
#  ' 21:07 ',
#  ' 21:07 ',
#  ' 21:08 ',
#  ' 21:33 ',
#  ' 21:42 ',
#  ' 21:44 ',
#  ' 06:32 ',
#  ' 06:32 ',
#  ' 06:52 ',
#  ' 06:53 ',
#  ' 06:53 ',
#  ' 06:53 ',
#  ' 06:53 ',
#  ' 06:54 ',
#  ' 07:25 ',
#  ' 07:26 ',
#  ' 07:26 ',
#  ' 07:26 ',
#  ' 08:50 ',
#  ' 08:51 ',
#  ' 08:51 ',
#  ' 08:51 ',
#  ' 08:52 ',
#  ' 08:52 ',
#  ' 08:53 ',
#  ' 08:53 ',
#  ' 08:53 ',
#  ' 08:53 ',
#  ' 08:54 ',
#  ' 08:54 ',
#  ' 08:55 ',
#  ' 08:56 ',
#  ' 08:56 ',
#  ' 08:56 ',
#  ' 08:59 ',
#  ' 08:59 ',
#  ' 09:00 ',
#  ' 10:04 ',
#  ' 10:04 ',
#  ' 10:04 ',
#  ' 10:04 ',
#  ' 10:04 ',
#  ' 10:04 ',
#  ' 10:04 ',
#  ' 10:05 ',
#  ' 10:05 ',
#  ' 10:05 ',
#  ' 10:05 ',
#  ' 10:05 ',
#  ' 10:06 ',
#  ' 10:07 ',
#  ' 10:07 ',
#  ' 10:08 ',
#  ' 10:08 ',
#  ' 10:08 ',
# ...

# %%
print(len(date),len(time),len(datalist))
# Out:
# 14965 14965 14965

# %%
df['Date'] = np.array(date)
df
# Out:
#                                                     Data      Date
# 0      16/08/18, 20:11 - Chinmayee created group "AGI...  16/08/18
# 1                  16/08/18, 20:11 - Chinmayee added you  16/08/18
# 2      16/08/18, 20:12 - Chinmayee: Hello this is off...  16/08/18
# 3                16/08/18, 20:12 - Jagas: Chusinam leaaa  16/08/18
# 4       16/08/18, 20:12 - +91 6309 604 570: Admin cheyyi  16/08/18
# ...                                                  ...       ...
# 14960  03/07/21, 13:03 - +91 90107 88369: Please join...  03/07/21
# 14961  03/07/21, 13:09 - Your security code with +91 ...  03/07/21
# 14962  03/07/21, 14:04 - +91 6304 605 703: All of you...  03/07/21
# 14963  03/07/21, 14:09 - +91 6304 605 703: Join the c...  03/07/21
# 14964  03/07/21, 15:04 - Nagalakshmi Ma'am 🐍💲: Please...  03/07/21
#
# [14965 rows x 2 columns]

# %%
df['Time'] = np.array(time)
df
# Out:
#                                                     Data      Date     Time
# 0      16/08/18, 20:11 - Chinmayee created group "AGI...  16/08/18   20:11
# 1                  16/08/18, 20:11 - Chinmayee added you  16/08/18   20:11
# 2      16/08/18, 20:12 - Chinmayee: Hello this is off...  16/08/18   20:12
# 3                16/08/18, 20:12 - Jagas: Chusinam leaaa  16/08/18   20:12
# 4       16/08/18, 20:12 - +91 6309 604 570: Admin cheyyi  16/08/18   20:12
# ...                                                  ...       ...      ...
# 14960  03/07/21, 13:03 - +91 90107 88369: Please join...  03/07/21   13:03
# 14961  03/07/21, 13:09 - Your security code with +91 ...  03/07/21   13:09
# 14962  03/07/21, 14:04 - +91 6304 605 703: All of you...  03/07/21   14:04
# 14963  03/07/21, 14:09 - +91 6304 605 703: Join the c...  03/07/21   14:09
# 14964  03/07/21, 15:04 - Nagalakshmi Ma'am 🐍💲: Please...  03/07/21   15:04
#
# [14965 rows x 3 columns]

# %%
datasep
# Out:
# [['16/08/18, 20:11 ', ' Chinmayee created group "AGI OFFICIAL@IT 2018', '22"'],
#  ['16/08/18, 20:11 ', ' Chinmayee added you'],
#  ['16/08/18, 20:12 ', ' Chinmayee: Hello this is official grup'],
#  ['16/08/18, 20:12 ', ' Jagas: Chusinam leaaa'],
#  ['16/08/18, 20:12 ', ' +91 6309 604 570: Admin cheyyi'],
#  ['16/08/18, 20:12 ', ' +91 6309 604 570: First'],
#  ['16/08/18, 20:12 ', ' Kalyan: Kkkk'],
#  ['16/08/18, 20:12 ', ' Chinmayee: No msg anything except studies'],
#  ['16/08/18, 20:12 ', ' Chinmayee: Hello sirs kuda unarru'],
#  ['16/08/18, 20:12 ', ' Chinmayee: Chusi matladu'],
#  ['16/08/18, 20:13 ', " You're now an admin"],
#  ['16/08/18, 20:13 ', ' Jagas: Adhea kadha cheppindhiii'],
#  ['16/08/18, 20:13 ', ' Chinmayee added Abhiramitb and S*2'],
#  ['16/08/18, 20:33 ', ' Meet: Nc job'],
#  ['16/08/18, 20:41 ', ' +91 91331 12884 left'],
#  ['16/08/18, 20:57 ',
#   ' Harifriend changed the subject from "AGI OFFICIAL@IT 2018',
#   '22" to "ONLY FOR STUDIES"'],
# ...

# %%
datasep
# Out:
# [['16/08/18, 20:11 ', ' Chinmayee created group "AGI OFFICIAL@IT 2018', '22"'],
#  ['16/08/18, 20:11 ', ' Chinmayee added you'],
#  ['16/08/18, 20:12 ', ' Chinmayee: Hello this is official grup'],
#  ['16/08/18, 20:12 ', ' Jagas: Chusinam leaaa'],
#  ['16/08/18, 20:12 ', ' +91 6309 604 570: Admin cheyyi'],
#  ['16/08/18, 20:12 ', ' +91 6309 604 570: First'],
#  ['16/08/18, 20:12 ', ' Kalyan: Kkkk'],
#  ['16/08/18, 20:12 ', ' Chinmayee: No msg anything except studies'],
#  ['16/08/18, 20:12 ', ' Chinmayee: Hello sirs kuda unarru'],
#  ['16/08/18, 20:12 ', ' Chinmayee: Chusi matladu'],
#  ['16/08/18, 20:13 ', " You're now an admin"],
#  ['16/08/18, 20:13 ', ' Jagas: Adhea kadha cheppindhiii'],
#  ['16/08/18, 20:13 ', ' Chinmayee added Abhiramitb and S*2'],
#  ['16/08/18, 20:33 ', ' Meet: Nc job'],
#  ['16/08/18, 20:41 ', ' +91 91331 12884 left'],
#  ['16/08/18, 20:57 ',
#   ' Harifriend changed the subject from "AGI OFFICIAL@IT 2018',
#   '22" to "ONLY FOR STUDIES"'],
# ...

# %%
datasep[0]
# Out:
# ['16/08/18, 20:11 ', ' Chinmayee created group "AGI OFFICIAL@IT 2018', '22"']

# %%
text = [datasep[i][1:] for i in range(len(datasep))]
text
# Out:
# [[' Chinmayee created group "AGI OFFICIAL@IT 2018', '22"'],
#  [' Chinmayee added you'],
#  [' Chinmayee: Hello this is official grup'],
#  [' Jagas: Chusinam leaaa'],
#  [' +91 6309 604 570: Admin cheyyi'],
#  [' +91 6309 604 570: First'],
#  [' Kalyan: Kkkk'],
#  [' Chinmayee: No msg anything except studies'],
#  [' Chinmayee: Hello sirs kuda unarru'],
#  [' Chinmayee: Chusi matladu'],
#  [" You're now an admin"],
#  [' Jagas: Adhea kadha cheppindhiii'],
#  [' Chinmayee added Abhiramitb and S*2'],
#  [' Meet: Nc job'],
#  [' +91 91331 12884 left'],
#  [' Harifriend changed the subject from "AGI OFFICIAL@IT 2018',
#   '22" to "ONLY FOR STUDIES"'],
#  [' +91 99484 61869: This message was deleted'],
#  [' +91 6309 604 570 added +91 91331 12884'],
#  [' You added Ali'],
#  [' +91 99484 61869: This message was deleted'],
#  [' Meet: <Media omitted>'],
#  [' Meet: This is the workshop manual everyone plz r8 your respective trait in the record with diagrams..'],
# ...

# %%
text[2][0].split(':')
# Out:
# [' Chinmayee', ' Hello this is official grup']

# %%
personname = []
for i in range(len(text)):
        try:
            personname.append(text[i][0].split(':')[0])
        
        except:
            personname.append(' ')

# %%
personname
# Out:
# [' Chinmayee created group "AGI OFFICIAL@IT 2018',
#  ' Chinmayee added you',
#  ' Chinmayee',
#  ' Jagas',
#  ' +91 6309 604 570',
#  ' +91 6309 604 570',
#  ' Kalyan',
#  ' Chinmayee',
#  ' Chinmayee',
#  ' Chinmayee',
#  " You're now an admin",
#  ' Jagas',
#  ' Chinmayee added Abhiramitb and S*2',
#  ' Meet',
#  ' +91 91331 12884 left',
#  ' Harifriend changed the subject from "AGI OFFICIAL@IT 2018',
#  ' +91 99484 61869',
#  ' +91 6309 604 570 added +91 91331 12884',
#  ' You added Ali',
#  ' +91 99484 61869',
#  ' Meet',
#  ' Meet',
#  ' Chinmayee',
#  ' Meet',
#  ' +91 6309 604 570',
#  ' Kalyan',
#  ' Kalyan',
#  ' Chinmayee',
#  ' +91 6309 604 570',
#  ' +91 6309 604 570',
#  ' +91 6309 604 570 added +91 90525 52661 and +91 99083 50196',
#  ' +91 6309 604 570',
#  ' +91 6309 604 570',
#  ' Ali',
#  ' +91 99083 50196',
#  ' +91 99083 50196',
#  ' +91 99083 50196',
#  ' +91 99083 50196',
#  ' Meet',
#  ' +91 99083 50196',
#  ' Meet',
#  ' +91 99083 50196',
# ...

# %%
print(len(personname))
# Out:
# 14965

# %%
df['Person'] = np.array(personname)
df.head()
# Out:
#                                                 Data      Date     Time  \
# 0  16/08/18, 20:11 - Chinmayee created group "AGI...  16/08/18   20:11
# 1              16/08/18, 20:11 - Chinmayee added you  16/08/18   20:11
# 2  16/08/18, 20:12 - Chinmayee: Hello this is off...  16/08/18   20:12
# 3            16/08/18, 20:12 - Jagas: Chusinam leaaa  16/08/18   20:12
# 4   16/08/18, 20:12 - +91 6309 604 570: Admin cheyyi  16/08/18   20:12
#
#                                            Person
# 0   Chinmayee created group "AGI OFFICIAL@IT 2018
# 1                             Chinmayee added you
# 2                                       Chinmayee
# 3                                           Jagas
# 4                                +91 6309 604 570

# %%
text[2][0].split(':')[1]
# Out:
# ' Hello this is official grup'

# %%
message = []

for i in range(len(text)):
        try:
            ans = text[i][0].split(':')[1]
            message.append(ans)
            
        except:
             message.append(' ')

# %%
message
# Out:
# [' ',
#  ' ',
#  ' Hello this is official grup',
#  ' Chusinam leaaa',
#  ' Admin cheyyi',
#  ' First',
#  ' Kkkk',
#  ' No msg anything except studies',
#  ' Hello sirs kuda unarru',
#  ' Chusi matladu',
#  ' ',
#  ' Adhea kadha cheppindhiii',
#  ' ',
#  ' Nc job',
#  ' ',
#  ' ',
#  ' This message was deleted',
#  ' ',
#  ' ',
#  ' This message was deleted',
#  ' <Media omitted>',
#  ' This is the workshop manual everyone plz r8 your respective trait in the record with diagrams..',
#  ' Today is holiday guys',
#  ' R8',
#  ' Holiday guys',
#  ' Krishna 2 marrow',
#  ' Unada',
#  ' That is not yet known',
#  ' Adhi telvad inka',
#  ' Emaina info vasthey pamputha',
#  ' ',
#  ' Guys I had added seniors to the group',
#  ' They pass the info',
#  ' Kk',
#  ' Hlo dudes',
#  ' This is Sujith',
#  ' U r senior from itb',
#  ' I am here to inform about u r dress code',
#  ' Yes Bhai..',
#  ' Except blazer ,white shirt,black pants and torn jeans u can wear any other things that u want',
# ...

# %%
print(len(message))
# Out:
# 14965

# %%
df['Message'] = np.array(message)
df
# Out:
#                                                     Data      Date     Time  \
# 0      16/08/18, 20:11 - Chinmayee created group "AGI...  16/08/18   20:11
# 1                  16/08/18, 20:11 - Chinmayee added you  16/08/18   20:11
# 2      16/08/18, 20:12 - Chinmayee: Hello this is off...  16/08/18   20:12
# 3                16/08/18, 20:12 - Jagas: Chusinam leaaa  16/08/18   20:12
# 4       16/08/18, 20:12 - +91 6309 604 570: Admin cheyyi  16/08/18   20:12
# ...                                                  ...       ...      ...
# 14960  03/07/21, 13:03 - +91 90107 88369: Please join...  03/07/21   13:03
# 14961  03/07/21, 13:09 - Your security code with +91 ...  03/07/21   13:09
# 14962  03/07/21, 14:04 - +91 6304 605 703: All of you...  03/07/21   14:04
# 14963  03/07/21, 14:09 - +91 6304 605 703: Join the c...  03/07/21   14:09
# 14964  03/07/21, 15:04 - Nagalakshmi Ma'am 🐍💲: Please...  03/07/21   15:04
#
#                                                   Person  \
# ...

# %%
import re

# %%
Pattern = re.compile("(0|91)?[7-9][0-9]{9}")
    return Pattern.match(s)

# %%
pattern = '{^\+?[0-9-]+$}'
pattercheck = re.compile("(0|91)?[7-9][0-9]{9}").match('9381437393')
pattercheck
# Out:
# <re.Match object; span=(0, 10), match='9381437393'>

# %%
re.match("(0|91)?[7-9][0-9]{9}",'0000')

# %%
persondata = list(df['Person'])
numbers = [persondata[i] for i in range(len(persondata)) if persondata[i].startswith('+') or persondata[i].startswith('9')]
numbers
# Out:
# ['9087425095',
#  '9.30 to avail the certifications as well as the value of the program. For more information contact EDP co',
#  '9087425095',
#  '9121623921',
#  '9963153383',
#  '9121623921',
#  '9000996237',
#  '9063917336',
#  '9121623921',
#  '9000106004',
#  '9908781196)',
#  '9052252689',
#  '9000578043',
#  '9,11']

# %%
numbers = [persondata[i] for i in range(len(persondata)) if re.match("(0|91)?[7-9][0-9]{9}",persondata[i])]
numbers
# Out:
# ['9087425095',
#  '8903612888)',
#  '9087425095',
#  '8903612888)',
#  '7674922431',
#  '9121623921',
#  '8247823829',
#  '8885668833',
#  '9963153383',
#  '7674922431',
#  '9121623921',
#  '8466014365',
#  '9000996237',
#  '7330838773',
#  '9063917336',
#  '9121623921',
#  '8466014365',
#  '8885093319',
#  '9000106004',
#  '9908781196)',
#  '8897784992*',
#  '8897784992*',
#  '9052252689',
#  '9000578043',
#  '7032812099',
#  '8096229754']

# %%
df
# Out:
#                                                     Data      Date     Time  \
# 0      16/08/18, 20:11 - Chinmayee created group "AGI...  16/08/18   20:11
# 1                  16/08/18, 20:11 - Chinmayee added you  16/08/18   20:11
# 2      16/08/18, 20:12 - Chinmayee: Hello this is off...  16/08/18   20:12
# 3                16/08/18, 20:12 - Jagas: Chusinam leaaa  16/08/18   20:12
# 4       16/08/18, 20:12 - +91 6309 604 570: Admin cheyyi  16/08/18   20:12
# ...                                                  ...       ...      ...
# 14960  03/07/21, 13:03 - +91 90107 88369: Please join...  03/07/21   13:03
# 14961  03/07/21, 13:09 - Your security code with +91 ...  03/07/21   13:09
# 14962  03/07/21, 14:04 - +91 6304 605 703: All of you...  03/07/21   14:04
# 14963  03/07/21, 14:09 - +91 6304 605 703: Join the c...  03/07/21   14:09
# 14964  03/07/21, 15:04 - Nagalakshmi Ma'am 🐍💲: Please...  03/07/21   15:04
#
#                                                   Person  \
# ...

# %%
df.to_csv('Whatsappedited.csv',index = None)
